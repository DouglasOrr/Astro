# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import astro
import logging
logging.getLogger().setLevel(logging.INFO)

# %%
astro.rl.train(astro.core.SOLO_CONFIG, interval=100, limit=10001, out='out/solo/qbot')
# Out:
# INFO:root:Logging training to: out/solo/qbot/001
# INFO:root:N: 0  VALID  t: 11 s
# INFO:root:N: 100  VALID  t: 7 s  TRAIN  #t: 35297  #s: 402  t: 4 s  survive: 0%
# INFO:root:N: 200  VALID  t: 6 s  TRAIN  #t: 40296  #s: 452  t: 5 s  survive: 0%
# INFO:root:N: 300  VALID  t: 4 s  TRAIN  #t: 34090  #s: 388  t: 5 s  survive: 0%
# INFO:root:N: 400  VALID  t: 2 s  TRAIN  #t: 35895  #s: 410  t: 6 s  survive: 0%
# INFO:root:N: 500  VALID  t: 10 s  TRAIN  #t: 40244  #s: 453  t: 6 s  survive: 0%
# INFO:root:N: 600  VALID  t: 5 s  TRAIN  #t: 41227  #s: 464  t: 6 s  survive: 0%
# INFO:root:N: 700  VALID  t: 13 s  TRAIN  #t: 39241  #s: 442  t: 5 s  survive: 1%
# INFO:root:N: 800  VALID  t: 4 s  TRAIN  #t: 37398  #s: 423  t: 5 s  survive: 1%
# INFO:root:N: 900  VALID  t: 7 s  TRAIN  #t: 48734  #s: 540  t: 7 s  survive: 0%
# INFO:root:N: 1000  VALID  t: 7 s  TRAIN  #t: 44334  #s: 495  t: 6 s  survive: 0%
# INFO:root:N: 1100  VALID  t: 4 s  TRAIN  #t: 37863  #s: 428  t: 6 s  survive: 0%
# ...
